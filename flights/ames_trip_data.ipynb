# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#import the countries data from the csv file with an index column of countries
df_ames = pd.read_csv("trip2NASA_Ames_Jun26to28_2023.csv")
#timestamp column to datetime 
df_ames['timestamp'] = pd.to_datetime(df_ames['timestamp'])
df_ames = df_ames.resample('H', on ='timestamp', axis=0).mean()
df_ames.head()
# Out:
#                         Chan_0_1    Chan_0_2     Chan_1_2
# timestamp
# 2023-06-25 22:00:00    57.125000   41.000000    54.250000
# 2023-06-25 23:00:00    53.183333   42.566667    50.050000
# 2023-06-26 00:00:00    51.666667   38.950000    47.600000
# 2023-06-26 01:00:00   860.033333  591.400000   802.483333
# 2023-06-26 02:00:00  1247.866667  844.416667  1151.133333

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')

ax1.plot(df_ames.index, df_ames['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_ames.index, df_ames['Chan_0_2'], color='green', linestyle="dashed")
ax1.plot(df_ames.index, df_ames['Chan_1_2'], color='purple')
#set the title
ax1.set_title('June 26th to June 28th 2023 Flight to Mountain View, CA')
#set the legend
ax1.legend(['Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#make zero mean and unit variance
df_ames_zmuv = df_ames.copy()
df_ames_zmuv['Chan_0_1'] = (df_ames_zmuv['Chan_0_1'] - df_ames_zmuv['Chan_0_1'].mean()) / df_ames_zmuv['Chan_0_1'].std()
df_ames_zmuv['Chan_0_2'] = (df_ames_zmuv['Chan_0_2'] - df_ames_zmuv['Chan_0_2'].mean()) / df_ames_zmuv['Chan_0_2'].std()
df_ames_zmuv['Chan_1_2'] = (df_ames_zmuv['Chan_1_2'] - df_ames_zmuv['Chan_1_2'].mean()) / df_ames_zmuv['Chan_1_2'].std()
df_ames_zmuv.head()
# Out:
#                      Chan_0_1  Chan_0_2  Chan_1_2
# timestamp
# 2023-06-25 22:00:00 -0.409766 -0.418573 -0.409846
# 2023-06-25 23:00:00 -0.418824 -0.413312 -0.420340
# 2023-06-26 00:00:00 -0.422310 -0.425456 -0.426461
# 2023-06-26 01:00:00  1.435416  1.429645  1.459531
# 2023-06-26 02:00:00  2.326705  2.279264  2.330594

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')

ax1.plot(df_ames_zmuv.index, df_ames_zmuv['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_ames_zmuv.index, df_ames_zmuv['Chan_0_2'], color='green', linestyle="dashed")
ax1.plot(df_ames_zmuv.index, df_ames_zmuv['Chan_1_2'], color='purple')
#set the title
ax1.set_title('June 26th to June 28th 2023 Flight to Mountain View, CA')
#set the legend
ax1.legend(['Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %% [markdown]
# MINUTE COUNTS

# %%
df_ames_arr = pd.read_csv("trip2NASA_Ames_Jun26to28_2023.csv")
#timestamp column to datetime 
df_ames_arr['timestamp'] = pd.to_datetime(df_ames['timestamp'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [8], line 3
#       1 df_ames_arr = pd.read_csv("trip2NASA_Ames_Jun26to28_2023.csv")
#       2 #timestamp column to datetime
# ----> 3 df_ames_arr['timestamp'] = pd.to_datetime(df_ames['timestamp'])
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'timestamp'

# %%
#plot dataframe above
fig, ax1 = plt.subplots(figsize=(20,10))
ax1.plot(df_ames_arr.index, df_ames_arr['Chan_0_1'], color='red', marker='.', markersize=2, linestyle='none', linewidth=0.5)
#ax1.plot(df_arr_india.index, df_arr_india['Chan_0_2'], color='green', linestyle="dashed")
#ax1.plot(df_arr_india.index, df_arr_india['Chan_1_2'], color='purple')

#set the title
ax1.set_title('Departure and Return Flights from Atlanta, GA to Mountain View, CA on June 26th, 2023 and June 28th, 2023')
#set the legend
ax1.legend(['CubeSat Channel_0_1 per Minute Counts'], loc='upper right')
