# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#import the countries data from the csv file with an index column of countries
df_morn = pd.read_csv("Old_Sensor_Wed12_Wed_19.csv")
#timestamp column to datetime 
df_morn['timestamp'] = pd.to_datetime(df_morn['timestamp'])
df_morn = df_morn.resample('H', on ='timestamp', axis=0).mean()


df_weather = pd.read_csv("week_together_weather.csv")
#timestamp column to datetime
df_weather['timestamp'] = pd.to_datetime(df_weather['Simple Date'])
df_weather = df_weather.set_index('timestamp')
df_weather = df_weather.drop(columns=['Date'])
df_weather = df_weather.drop(columns=['Simple Date'])
# Resample to hourly data points
df_weather = df_weather.resample('H').mean()
# View the first few rows of the resampled dataframe
#print(df_weather.head())

#combined both datasets on the timestamp index
df_combined_1 = pd.concat([df_morn, df_weather], axis=1, join='outer')
df_combined_1.dropna(inplace=True)
df_combined_1.head()
# Out:
#                       Chan_0_1   Chan_0_2   Chan_1_2  \
# timestamp
# 2023-04-12 00:00:00  89.233333  40.916667  51.916667
# 2023-04-12 01:00:00  91.616667  41.950000  54.233333
# 2023-04-12 02:00:00  88.800000  40.116667  50.116667
# 2023-04-12 03:00:00  94.083333  41.900000  52.466667
# 2023-04-12 04:00:00  99.300000  42.416667  55.150000
#
#                      Outdoor Temperature (°F)  Wind Speed (mph)  \
# timestamp
# 2023-04-12 00:00:00                 52.100000               0.0
# 2023-04-12 01:00:00                 50.558333               0.0
# 2023-04-12 02:00:00                 48.366667               0.0
# 2023-04-12 03:00:00                 47.008333               0.0
# 2023-04-12 04:00:00                 45.558333               0.0
#
#                      Wind Gust (mph)  Max Daily Gust (mph)  \
# timestamp
# 2023-04-12 00:00:00              0.0                   0.0
# 2023-04-12 01:00:00              0.0                   0.0
# ...

# %%
#import the countries data from the csv file with an index column of countries
df_morn = pd.read_csv("cubeSat_0xEE.csv")
#timestamp column to datetime 
df_morn['timestamp'] = pd.to_datetime(df_morn['timestamp'])
df_morn = df_morn.resample('H', on ='timestamp', axis=0).mean()


df_weather = pd.read_csv("week_together_weather.csv")
#timestamp column to datetime
df_weather['timestamp'] = pd.to_datetime(df_weather['Simple Date'])
df_weather = df_weather.set_index('timestamp')
df_weather = df_weather.drop(columns=['Date'])
df_weather = df_weather.drop(columns=['Simple Date'])
df_weather = df_weather.resample('H').mean()
#df_weather.head()

#combined both datasets on the timestamp index
df_combined_2 = pd.concat([df_morn, df_weather], axis=1, join='outer')
df_combined_2.dropna(inplace=True)
df_combined_2.head()
# Out:
#                       Chan_0_1   Chan_0_2   Chan_1_2  \
# timestamp
# 2023-04-11 00:00:00  58.916667  70.783333  69.166667
# 2023-04-11 01:00:00  58.683333  70.616667  68.800000
# 2023-04-11 02:00:00  59.116667  70.933333  68.266667
# 2023-04-11 03:00:00  59.316667  71.883333  69.433333
# 2023-04-11 04:00:00  59.883333  70.933333  70.266667
#
#                      Outdoor Temperature (°F)  Wind Speed (mph)  \
# timestamp
# 2023-04-11 00:00:00                 54.858333          0.066667
# 2023-04-11 01:00:00                 53.608333          0.000000
# 2023-04-11 02:00:00                 52.650000          0.058333
# 2023-04-11 03:00:00                 51.616667          0.016667
# 2023-04-11 04:00:00                 50.733333          0.016667
#
#                      Wind Gust (mph)  Max Daily Gust (mph)  \
# timestamp
# 2023-04-11 00:00:00         0.275000              2.516667
# 2023-04-11 01:00:00         0.000000              3.400000
# ...

# %%
#combined all 9 datasets into one df with timestamp as index
df_combined = pd.concat([df_combined_1, df_combined_2], axis=0, join='inner')
df_combined.dropna(inplace=True)
df_combined.head()
# Out:
#                       Chan_0_1   Chan_0_2   Chan_1_2  \
# timestamp
# 2023-04-12 00:00:00  89.233333  40.916667  51.916667
# 2023-04-12 01:00:00  91.616667  41.950000  54.233333
# 2023-04-12 02:00:00  88.800000  40.116667  50.116667
# 2023-04-12 03:00:00  94.083333  41.900000  52.466667
# 2023-04-12 04:00:00  99.300000  42.416667  55.150000
#
#                      Outdoor Temperature (°F)  Wind Speed (mph)  \
# timestamp
# 2023-04-12 00:00:00                 52.100000               0.0
# 2023-04-12 01:00:00                 50.558333               0.0
# 2023-04-12 02:00:00                 48.366667               0.0
# 2023-04-12 03:00:00                 47.008333               0.0
# 2023-04-12 04:00:00                 45.558333               0.0
#
#                      Wind Gust (mph)  Max Daily Gust (mph)  \
# timestamp
# 2023-04-12 00:00:00              0.0                   0.0
# 2023-04-12 01:00:00              0.0                   0.0
# ...

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
ax1.plot(df_combined_1.index, df_combined_1['Humidity (%)'], color='red', linestyle='--')
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
ax1.plot(df_combined_1.index, df_combined_1['Outdoor Temperature (°F)'], color='green', linestyle='dotted')
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
ax1.plot(df_combined_1.index, df_combined_1['Relative Pressure (inHg)'], color='orange', linestyle='dashdot')
ax1.plot(df_combined_1.index, df_combined_1['Chan_0_1'], color='blue')
ax1.plot(df_combined_1.index, df_combined_1['Chan_0_2'], color='pink')
ax1.plot(df_combined_1.index, df_combined_1['Chan_1_2'], color='purple')
#set the title
ax1.set_title('April 12 to April 19 Old Sensor and Weather Data')
#set the legend
ax1.legend(['Humidity', 'Temperature', 'Relative Pressure', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
#ax1.plot(df_combined.index, df_combined['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
ax1.plot(df_combined_1.index, df_combined_1['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
#ax1.plot(df_scaled_1.index, df_scaled_1['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_combined_1.index, df_combined_1['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_combined_1.index, df_combined_1['Chan_0_2'], color='green')
ax1.plot(df_combined_1.index, df_combined_1['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 Old Sensor and Weather Data')
#set the legend
ax1.legend(['Temperature', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
ax1.plot(df_combined_1.index, df_combined_1['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
#ax1.plot(df_combined_1.index, df_combined_1['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
#ax1.plot(df_scaled_1.index, df_scaled_1['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_combined_1.index, df_combined_1['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_combined_1.index, df_combined_1['Chan_0_2'], color='green')
ax1.plot(df_combined_1.index, df_combined_1['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 Old Sensor and Weather Data')
#set the legend
ax1.legend(['Humidity', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
#ax1.plot(df_combined_1.index, df_combined_1['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
#ax1.plot(df_combined_1.index, df_combined_1['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
ax1.plot(df_combined_1.index, df_combined_1['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_combined_1.index, df_combined_1['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_combined_1.index, df_combined_1['Chan_0_2'], color='green')
ax1.plot(df_combined_1.index, df_combined_1['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 Old Sensor and Weather Data')
#set the legend
ax1.legend(['Pressure', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#make zero mean and unit variance
df_scaled_1 = df_combined_1.copy()
df_scaled_1['Chan_0_1'] = (df_scaled_1['Chan_0_1'] - df_scaled_1['Chan_0_1'].mean()) / df_scaled_1['Chan_0_1'].std()
df_scaled_1['Chan_0_2'] = (df_scaled_1['Chan_0_2'] - df_scaled_1['Chan_0_2'].mean()) / df_scaled_1['Chan_0_2'].std()
df_scaled_1['Chan_1_2'] = (df_scaled_1['Chan_1_2'] - df_scaled_1['Chan_1_2'].mean()) / df_scaled_1['Chan_1_2'].std()
df_scaled_1['Humidity (%)'] = (df_scaled_1['Humidity (%)'] - df_scaled_1['Humidity (%)'].mean()) / df_scaled_1['Humidity (%)'].std()
df_scaled_1['Outdoor Temperature (°F)'] = (df_scaled_1['Outdoor Temperature (°F)'] - df_scaled_1['Outdoor Temperature (°F)'].mean()) / df_scaled_1['Outdoor Temperature (°F)'].std()
df_scaled_1['Relative Pressure (inHg)'] = (df_scaled_1['Relative Pressure (inHg)'] - df_scaled_1['Relative Pressure (inHg)'].mean()) / df_scaled_1['Relative Pressure (inHg)'].std()
df_scaled_1.head()
# Out:
#                      Chan_0_1  Chan_0_2  Chan_1_2  Outdoor Temperature (°F)  \
# timestamp
# 2023-04-12 00:00:00  0.838378  1.200259  1.043929                 -1.267119
# 2023-04-12 01:00:00  0.889941  1.285548  1.317881                 -1.446342
# 2023-04-12 02:00:00  0.829002  1.134229  0.831074                 -1.701129
# 2023-04-12 03:00:00  0.943308  1.281421  1.108968                 -1.859040
# 2023-04-12 04:00:00  1.056172  1.324065  1.426280                 -2.027606
#
#                      Wind Speed (mph)  Wind Gust (mph)  Max Daily Gust (mph)  \
# timestamp
# 2023-04-12 00:00:00               0.0              0.0                   0.0
# 2023-04-12 01:00:00               0.0              0.0                   0.0
# 2023-04-12 02:00:00               0.0              0.0                   0.0
# 2023-04-12 03:00:00               0.0              0.0                   0.0
# 2023-04-12 04:00:00               0.0              0.0                   0.0
#
# ...

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
ax1.plot(df_scaled_1.index, df_scaled_1['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
#ax1.plot(df_combined_1.index, df_combined_1['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
#ax1.plot(df_combined_1.index, df_combined_1['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_scaled_1.index, df_scaled_1['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_scaled_1.index, df_scaled_1['Chan_0_2'], color='green')
ax1.plot(df_scaled_1.index, df_scaled_1['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 Old Sensor and Weather Data')
#set the legend
ax1.legend(['Humidity', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
#ax1.plot(df_scaled_1.index, df_scaled_1['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
ax1.plot(df_scaled_1.index, df_scaled_1['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
#ax1.plot(df_combined_1.index, df_combined_1['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_scaled_1.index, df_scaled_1['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_scaled_1.index, df_scaled_1['Chan_0_2'], color='green')
ax1.plot(df_scaled_1.index, df_scaled_1['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 Old Sensor and Weather Data')
#set the legend
ax1.legend(['Temperature', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
#ax1.plot(df_scaled_1.index, df_scaled_1['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
#ax1.plot(df_scaled_1.index, df_scaled_1['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
ax1.plot(df_scaled_1.index, df_scaled_1['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_scaled_1.index, df_scaled_1['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_scaled_1.index, df_scaled_1['Chan_0_2'], color='green')
ax1.plot(df_scaled_1.index, df_scaled_1['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 Old Sensor and Weather Data')
#set the legend
ax1.legend(['Pressure', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
#ax1.plot(df_combined_1.index, df_combined_1['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
#ax1.plot(df_combined_1.index, df_combined_1['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
ax1.plot(df_combined_2.index, df_combined_2['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_combined_2.index, df_combined_2['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_combined_2.index, df_combined_2['Chan_0_2'], color='green')
ax1.plot(df_combined_2.index, df_combined_2['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 New Sensor and Weather Data')
#set the legend
ax1.legend(['Pressure', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
#ax1.plot(df_combined_1.index, df_combined_1['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
ax1.plot(df_combined_2.index, df_combined_2['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
#ax1.plot(df_combined_2.index, df_combined_2['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_combined_2.index, df_combined_2['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_combined_2.index, df_combined_2['Chan_0_2'], color='green')
ax1.plot(df_combined_2.index, df_combined_2['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 New Sensor and Weather Data')
#set the legend
ax1.legend(['Temperature', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
ax1.plot(df_combined_2.index, df_combined_2['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
#ax1.plot(df_combined_2.index, df_combined_2['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
#ax1.plot(df_combined_2.index, df_combined_2['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_combined_2.index, df_combined_2['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_combined_2.index, df_combined_2['Chan_0_2'], color='green')
ax1.plot(df_combined_2.index, df_combined_2['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 New Sensor and Weather Data')
#set the legend
ax1.legend(['Humidity', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#make zero mean and unit variance
df_scaled_2 = df_combined_2.copy()
df_scaled_2['Chan_0_1'] = (df_scaled_2['Chan_0_1'] - df_scaled_2['Chan_0_1'].mean()) / df_scaled_2['Chan_0_1'].std()
df_scaled_2['Chan_0_2'] = (df_scaled_2['Chan_0_2'] - df_scaled_2['Chan_0_2'].mean()) / df_scaled_2['Chan_0_2'].std()
df_scaled_2['Chan_1_2'] = (df_scaled_2['Chan_1_2'] - df_scaled_2['Chan_1_2'].mean()) / df_scaled_2['Chan_1_2'].std()
df_scaled_2['Humidity (%)'] = (df_scaled_2['Humidity (%)'] - df_scaled_2['Humidity (%)'].mean()) / df_scaled_2['Humidity (%)'].std()
df_scaled_2['Outdoor Temperature (°F)'] = (df_scaled_2['Outdoor Temperature (°F)'] - df_scaled_2['Outdoor Temperature (°F)'].mean()) / df_scaled_2['Outdoor Temperature (°F)'].std()
df_scaled_2['Relative Pressure (inHg)'] = (df_scaled_2['Relative Pressure (inHg)'] - df_scaled_2['Relative Pressure (inHg)'].mean()) / df_scaled_2['Relative Pressure (inHg)'].std()
df_scaled_2.head()
# Out:
#                      Chan_0_1  Chan_0_2  Chan_1_2  Outdoor Temperature (°F)  \
# timestamp
# 2023-04-11 00:00:00  2.412757  3.162042  2.692521                 -0.864138
# 2023-04-11 01:00:00  2.383478  3.148072  2.659376                 -1.003218
# 2023-04-11 02:00:00  2.437853  3.174614  2.611164                 -1.109847
# 2023-04-11 03:00:00  2.462949  3.254240  2.716627                 -1.224820
# 2023-04-11 04:00:00  2.534053  3.174614  2.791958                 -1.323103
#
#                      Wind Speed (mph)  Wind Gust (mph)  Max Daily Gust (mph)  \
# timestamp
# 2023-04-11 00:00:00          0.066667         0.275000              2.516667
# 2023-04-11 01:00:00          0.000000         0.000000              3.400000
# 2023-04-11 02:00:00          0.058333         0.091667              3.400000
# 2023-04-11 03:00:00          0.016667         0.091667              3.400000
# 2023-04-11 04:00:00          0.016667         0.091667              3.400000
#
# ...

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
#ax1.plot(df_scaled_1.index, df_scaled_1['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
#ax1.plot(df_scaled_1.index, df_scaled_1['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
ax1.plot(df_scaled_2.index, df_scaled_2['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_scaled_2.index, df_scaled_2['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_scaled_2.index, df_scaled_2['Chan_0_2'], color='green')
ax1.plot(df_scaled_2.index, df_scaled_2['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 Old Sensor and Weather Data')
#set the legend
ax1.legend(['Pressure', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
#ax1.plot(df_scaled_1.index, df_scaled_1['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
ax1.plot(df_scaled_2.index, df_scaled_2['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
#ax1.plot(df_scaled_2.index, df_scaled_2['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_scaled_2.index, df_scaled_2['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_scaled_2.index, df_scaled_2['Chan_0_2'], color='green')
ax1.plot(df_scaled_2.index, df_scaled_2['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 Old Sensor and Weather Data')
#set the legend
ax1.legend(['Temperature', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
#ax1.plot(df_combined.index, df_combined['average'], color='blue')
ax1.set_xlabel('Time')
#ax1.set_ylabel('Average Counts', color='blue')
#plot humidity on the second axis
ax1.plot(df_scaled_2.index, df_scaled_2['Humidity (%)'], color='red', dashes=[6, 2])
#ax2.set_ylabel('Humidity', color='red')
#plot temperature on the third axis
#ax1.plot(df_scaled_2.index, df_scaled_2['Outdoor Temperature (°F)'], color='orange', dashes=[6, 2])
#ax3.set_ylabel('Temperature', color='green')
#plot pressure on the fourth axis
#ax1.plot(df_scaled_2.index, df_scaled_2['Relative Pressure (inHg)'], color='gold', dashes=[6, 2])
ax1.plot(df_scaled_2.index, df_scaled_2['Chan_0_1'], color='blue', linestyle='dotted')
ax1.plot(df_scaled_2.index, df_scaled_2['Chan_0_2'], color='green')
ax1.plot(df_scaled_2.index, df_scaled_2['Chan_1_2'], color='purple', linestyle='dashdot')
#set the title
ax1.set_title('April 12 to April 19 Old Sensor and Weather Data')
#set the legend
ax1.legend(['Humidity', 'Channel_0_1', 'Channel_0_2', 'Channel_1_2'], loc='upper left')

# %%
df_scaled_1['average'] = df_scaled_1[['Chan_0_1', 'Chan_0_2', 'Chan_1_2']].mean(axis=1)
df_scaled_1.head()
# Out:
#                      Chan_0_1  Chan_0_2  Chan_1_2  Outdoor Temperature (°F)  \
# timestamp
# 2023-04-12 00:00:00  0.838378  1.200259  1.043929                 -1.267119
# 2023-04-12 01:00:00  0.889941  1.285548  1.317881                 -1.446342
# 2023-04-12 02:00:00  0.829002  1.134229  0.831074                 -1.701129
# 2023-04-12 03:00:00  0.943308  1.281421  1.108968                 -1.859040
# 2023-04-12 04:00:00  1.056172  1.324065  1.426280                 -2.027606
#
#                      Wind Speed (mph)  Wind Gust (mph)  Max Daily Gust (mph)  \
# timestamp
# 2023-04-12 00:00:00               0.0              0.0                   0.0
# 2023-04-12 01:00:00               0.0              0.0                   0.0
# 2023-04-12 02:00:00               0.0              0.0                   0.0
# 2023-04-12 03:00:00               0.0              0.0                   0.0
# 2023-04-12 04:00:00               0.0              0.0                   0.0
#
# ...

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
ax1.plot(df_scaled_1.index, df_scaled_1['average'], color='green', label='Average Counts', marker='o')
ax1.set_xlabel('Time')
#plot humidity on the second axis
#ax1.plot(df_combined.index, df_combined['Humidity (%)'], color='red', dashes=[6, 2])
#plot temperature on the third axis
ax1.plot(df_scaled_1.index, df_scaled_1['Outdoor Temperature (°F)'], color='blue', linestyle='dotted', label='Temperature')
#plot pressure on the fourth axis
ax1.plot(df_scaled_1.index, df_scaled_1['Relative Pressure (inHg)'], color='red', linestyle='dashdot', label='Pressure')
#set the title
ax1.set_title('April 12 to April 19 Average Counts and Temperature Data - Old Sensors')
#set the legend
ax1.legend()

# %%
df_scaled_2['average'] = df_scaled_2[['Chan_0_1', 'Chan_0_2', 'Chan_1_2']].mean(axis=1)
df_scaled_2.head()
# Out:
#                      Chan_0_1  Chan_0_2  Chan_1_2  Outdoor Temperature (°F)  \
# timestamp
# 2023-04-11 00:00:00  2.412757  3.162042  2.692521                 -0.864138
# 2023-04-11 01:00:00  2.383478  3.148072  2.659376                 -1.003218
# 2023-04-11 02:00:00  2.437853  3.174614  2.611164                 -1.109847
# 2023-04-11 03:00:00  2.462949  3.254240  2.716627                 -1.224820
# 2023-04-11 04:00:00  2.534053  3.174614  2.791958                 -1.323103
#
#                      Wind Speed (mph)  Wind Gust (mph)  Max Daily Gust (mph)  \
# timestamp
# 2023-04-11 00:00:00          0.066667         0.275000              2.516667
# 2023-04-11 01:00:00          0.000000         0.000000              3.400000
# 2023-04-11 02:00:00          0.058333         0.091667              3.400000
# 2023-04-11 03:00:00          0.016667         0.091667              3.400000
# 2023-04-11 04:00:00          0.016667         0.091667              3.400000
#
# ...

# %%
#plot the figure with multiple axes
fig, ax1 = plt.subplots(figsize=(20,10))
#plot average counts on the first axis
ax1.plot(df_scaled_2.index, df_scaled_2['average'], color='green', label='Average Counts', marker='o')
ax1.set_xlabel('Time')
#plot humidity on the second axis
#ax1.plot(df_combined.index, df_combined['Humidity (%)'], color='red', dashes=[6, 2])
#plot temperature on the third axis
ax1.plot(df_scaled_2.index, df_scaled_2['Outdoor Temperature (°F)'], color='blue', linestyle='dotted', label='Temperature')
#plot pressure on the fourth axis
ax1.plot(df_scaled_2.index, df_scaled_2['Relative Pressure (inHg)'], color='red', linestyle='dashdot', label='Pressure')
#set the title
ax1.set_title('April 12 to April 19 Average Counts and Temperature Data - New Sensors')
#set the legend
ax1.legend()
