# %%
import numpy as np
import pandas as pd
from math import radians, sin, cos, sqrt, atan2, ceil, floor
# Out:
# d:\Anaconda\envs\ML\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# d:\Anaconda\envs\ML\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# d:\Anaconda\envs\ML\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
#calculate distance between two points - origin natural science center building
def calculate_distance(lat2, lon2):
    R = 3958.8  # radius of the Earth in miles
    lat1, lon1 = 33.75370509057149, -84.3879949313794
    lat1_rad = radians(lat1)
    lon1_rad = radians(lon1)
    lat2_rad = radians(lat2)
    lon2_rad = radians(lon2)
    dlon = lon2_rad - lon1_rad
    dlat = lat2_rad - lat1_rad
    a = sin(dlat / 2) ** 2 + cos(lat1_rad) * cos(lat2_rad) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    dist = R * c
    return dist

# %%
muon = pd.read_csv('./week_testing/abbaas_home.csv')
weather = pd.read_csv('./weather_data/downtown.csv')
muon = muon[['timestamp','Chan_0_1','Chan_0_2','Chan_1_2']]
muon['timestamp'] = pd.to_datetime(muon['timestamp'])
weather.drop('Date', axis=1, inplace=True)
weather['Simple Date'] = pd.to_datetime(weather['Simple Date'])
#filter out the weather data in the range of the muon data
weather = weather[(weather['Simple Date'] >= muon['timestamp'].min()) & (weather['Simple Date'] <= muon['timestamp'].max())]
weather.set_index('Simple Date', inplace=True)
location = 'Abbaas Home'
date = str(muon['timestamp'].min()) + ' to ' + str(muon['timestamp'].max())
max_muon_0_1 = muon['Chan_0_1'].max()
min_muon_0_1 = muon['Chan_0_1'].min()
max_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmax()]['timestamp']
min_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmin()]['timestamp']
median_muon_0_1 = muon['Chan_0_1'].median()
max_muon_0_2 = muon['Chan_0_2'].max()
min_muon_0_2 = muon['Chan_0_2'].min()
max_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmax()]['timestamp']
min_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmin()]['timestamp']
median_muon_0_2 = muon['Chan_0_2'].median()
max_muon_1_2 = muon['Chan_1_2'].max()
min_muon_1_2 = muon['Chan_1_2'].min()
max_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmax()]['timestamp']
min_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmin()]['timestamp']
median_muon_1_2 = muon['Chan_1_2'].median()
avg_temp = weather['Outdoor Temperature (°F)'].median()
max_temp = weather['Outdoor Temperature (°F)'].max()
min_temp = weather['Outdoor Temperature (°F)'].min()
max_temp_time = weather.idxmax()['Outdoor Temperature (°F)']
min_temp_time = weather.idxmin()['Outdoor Temperature (°F)']
avg_humidity = weather['Humidity (%)'].median()
max_humidity = weather['Humidity (%)'].max()
min_humidity = weather['Humidity (%)'].min()
max_humidity_time = weather.idxmax()['Humidity (%)']
min_humidity_time = weather.idxmin()['Humidity (%)']
avg_pressure = weather['Relative Pressure (inHg)'].median()
max_pressure = weather['Relative Pressure (inHg)'].max()
min_pressure = weather['Relative Pressure (inHg)'].min()
max_pressure_time = weather.idxmax()['Relative Pressure (inHg)']
min_pressure_time = weather.idxmin()['Relative Pressure (inHg)']
is_raining = weather['Event Rain (in)'].max() > 0
max_rain = weather['Event Rain (in)'].max()
max_rain_time = weather.idxmax()['Event Rain (in)']
solar_radiation_median = weather['Solar Radiation (W/m^2)'].median()
solar_radiation_max = weather['Solar Radiation (W/m^2)'].max()
solar_radiation_max_time = weather.idxmax()['Solar Radiation (W/m^2)']
solar_radiation_min = weather['Solar Radiation (W/m^2)'].min()
solar_radiation_min_time = weather.idxmin()['Solar Radiation (W/m^2)']
ultra_violet_median = weather['Ultra-Violet Radiation Index'].median()
ultra_violet_max = weather['Ultra-Violet Radiation Index'].max()
ultra_violet_max_time = weather.idxmax()['Ultra-Violet Radiation Index']
ultra_violet_min = weather['Ultra-Violet Radiation Index'].min()
ultra_violet_min_time = weather.idxmin()['Ultra-Violet Radiation Index']
distance = calculate_distance(33.749676408826566, -84.39103090254359)
Position = 'by the window'
# create a dictionary of the data
data = {'Location': location, 
'Date': date, 
'Max Muon_0_1': max_muon_0_1, 
'Max Muon Time_0_1': max_muon_time_0_1, 
'Min Muon_0_1': min_muon_0_1, 
'Min Muon Time_0_1': min_muon_time_0_1, 
'median Muon_0_1': median_muon_0_1,
'median Muon ceiling_0_1': ceil(median_muon_0_1),
'median Muon floor_0_1': floor(median_muon_0_1),
'median Muon round_0_1': round(median_muon_0_1),
'Max Muon_0_2': max_muon_0_2, 
'Max Muon Time_0_2': max_muon_time_0_2, 
'Min Muon_0_2': min_muon_0_2, 
'Min Muon Time_0_2': min_muon_time_0_2, 
'median Muon_0_2': median_muon_0_2,
'median Muon ceiling_0_2': ceil(median_muon_0_2),
'median Muon floor_0_2': floor(median_muon_0_2),
'median Muon round_0_2': round(median_muon_0_2),
'Max Muon_1_2': max_muon_1_2, 
'Max Muon Time_1_2': max_muon_time_1_2, 
'Min Muon_1_2': min_muon_1_2, 
'Min Muon Time_1_2': min_muon_time_1_2, 
'median Muon_1_2': median_muon_1_2,
'median Muon ceiling_1_2': ceil(median_muon_1_2),
'median Muon floor_1_2': floor(median_muon_1_2),
'median Muon round_1_2': round(median_muon_1_2),
'Avg Temp': avg_temp, 
'Max Temp': max_temp, 
'Max Temp Time': max_temp_time,
'Min Temp': min_temp,  
'Min Temp Time': min_temp_time, 
'Avg Humidity': avg_humidity, 
'Max Humidity': max_humidity, 
'Max Humidity Time': max_humidity_time,
'Min Humidity': min_humidity,  
'Min Humidity Time': min_humidity_time, 
'Avg Pressure': avg_pressure, 
'Max Pressure': max_pressure, 
'Max Pressure Time': max_pressure_time,
'Min Pressure': min_pressure,  
'Min Pressure Time': min_pressure_time, 
'Is Raining': is_raining, 
'Max Rain': max_rain, 
'Max Rain Time': max_rain_time, 
'Solar Radiation median': solar_radiation_median, 
'Solar Radiation Max': solar_radiation_max, 
'Solar Radiation Max Time': solar_radiation_max_time, 
'Solar Radiation Min': solar_radiation_min, 
'Solar Radiation Min Time': solar_radiation_min_time, 
'Ultra Violet median': ultra_violet_median, 
'Ultra Violet Max': ultra_violet_max, 
'Ultra Violet Max Time': ultra_violet_max_time, 
'Ultra Violet Min': ultra_violet_min, 
'Ultra Violet Min Time': ultra_violet_min_time, 
'Distance': distance, 
'Position': Position}
# create a dataframe from the data
df = pd.DataFrame(data, index=[0])

# %%
muon = pd.read_csv('./week_testing/andy_new.csv')
weather = pd.read_csv('./weather_data/downtown_andy.csv')
muon = muon[['timestamp','Chan_0_1','Chan_0_2','Chan_1_2']]
muon['timestamp'] = pd.to_datetime(muon['timestamp'])
weather.drop('Date', axis=1, inplace=True)
weather['Simple Date'] = pd.to_datetime(weather['Simple Date'])
#filter out the weather data in the range of the muon data
weather = weather[(weather['Simple Date'] >= muon['timestamp'].min()) & (weather['Simple Date'] <= muon['timestamp'].max())]
weather.set_index('Simple Date', inplace=True)
location = 'Andy Home'
date = str(muon['timestamp'].min()) + ' to ' + str(muon['timestamp'].max())
max_muon_0_1 = muon['Chan_0_1'].max()
min_muon_0_1 = muon['Chan_0_1'].min()
max_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmax()]['timestamp']
min_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmin()]['timestamp']
median_muon_0_1 = muon['Chan_0_1'].median()
max_muon_0_2 = muon['Chan_0_2'].max()
min_muon_0_2 = muon['Chan_0_2'].min()
max_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmax()]['timestamp']
min_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmin()]['timestamp']
median_muon_0_2 = muon['Chan_0_2'].median()
max_muon_1_2 = muon['Chan_1_2'].max()
min_muon_1_2 = muon['Chan_1_2'].min()
max_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmax()]['timestamp']
min_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmin()]['timestamp']
median_muon_1_2 = muon['Chan_1_2'].median()
avg_temp = weather['Outdoor Temperature (°F)'].median()
max_temp = weather['Outdoor Temperature (°F)'].max()
min_temp = weather['Outdoor Temperature (°F)'].min()
max_temp_time = weather.idxmax()['Outdoor Temperature (°F)']
min_temp_time = weather.idxmin()['Outdoor Temperature (°F)']
avg_humidity = weather['Humidity (%)'].median()
max_humidity = weather['Humidity (%)'].max()
min_humidity = weather['Humidity (%)'].min()
max_humidity_time = weather.idxmax()['Humidity (%)']
min_humidity_time = weather.idxmin()['Humidity (%)']
avg_pressure = weather['Relative Pressure (inHg)'].median()
max_pressure = weather['Relative Pressure (inHg)'].max()
min_pressure = weather['Relative Pressure (inHg)'].min()
max_pressure_time = weather.idxmax()['Relative Pressure (inHg)']
min_pressure_time = weather.idxmin()['Relative Pressure (inHg)']
is_raining = weather['Event Rain (in)'].max() > 0
max_rain = weather['Event Rain (in)'].max()
max_rain_time = weather.idxmax()['Event Rain (in)']
solar_radiation_median = weather['Solar Radiation (W/m^2)'].median()
solar_radiation_max = weather['Solar Radiation (W/m^2)'].max()
solar_radiation_max_time = weather.idxmax()['Solar Radiation (W/m^2)']
solar_radiation_min = weather['Solar Radiation (W/m^2)'].min()
solar_radiation_min_time = weather.idxmin()['Solar Radiation (W/m^2)']
ultra_violet_median = weather['Ultra-Violet Radiation Index'].median()
ultra_violet_max = weather['Ultra-Violet Radiation Index'].max()
ultra_violet_max_time = weather.idxmax()['Ultra-Violet Radiation Index']
ultra_violet_min = weather['Ultra-Violet Radiation Index'].min()
ultra_violet_min_time = weather.idxmin()['Ultra-Violet Radiation Index']
distance = calculate_distance(33.752198545118624, -84.37815567993422)
Position = 'by the closet away from the window'
# create a dictionary of the data
data = {'Location': location, 
'Date': date, 
'Max Muon_0_1': max_muon_0_1, 
'Max Muon Time_0_1': max_muon_time_0_1, 
'Min Muon_0_1': min_muon_0_1, 
'Min Muon Time_0_1': min_muon_time_0_1, 
'median Muon_0_1': median_muon_0_1,
'median Muon ceiling_0_1': ceil(median_muon_0_1),
'median Muon floor_0_1': floor(median_muon_0_1),
'median Muon round_0_1': round(median_muon_0_1),
'Max Muon_0_2': max_muon_0_2, 
'Max Muon Time_0_2': max_muon_time_0_2, 
'Min Muon_0_2': min_muon_0_2, 
'Min Muon Time_0_2': min_muon_time_0_2, 
'median Muon_0_2': median_muon_0_2,
'median Muon ceiling_0_2': ceil(median_muon_0_2),
'median Muon floor_0_2': floor(median_muon_0_2),
'median Muon round_0_2': round(median_muon_0_2),
'Max Muon_1_2': max_muon_1_2, 
'Max Muon Time_1_2': max_muon_time_1_2, 
'Min Muon_1_2': min_muon_1_2, 
'Min Muon Time_1_2': min_muon_time_1_2, 
'median Muon_1_2': median_muon_1_2,
'median Muon ceiling_1_2': ceil(median_muon_1_2),
'median Muon floor_1_2': floor(median_muon_1_2),
'median Muon round_1_2': round(median_muon_1_2),
'Avg Temp': avg_temp, 
'Max Temp': max_temp, 
'Max Temp Time': max_temp_time,
'Min Temp': min_temp,  
'Min Temp Time': min_temp_time, 
'Avg Humidity': avg_humidity, 
'Max Humidity': max_humidity, 
'Max Humidity Time': max_humidity_time,
'Min Humidity': min_humidity,  
'Min Humidity Time': min_humidity_time, 
'Avg Pressure': avg_pressure, 
'Max Pressure': max_pressure, 
'Max Pressure Time': max_pressure_time,
'Min Pressure': min_pressure,  
'Min Pressure Time': min_pressure_time, 
'Is Raining': is_raining, 
'Max Rain': max_rain, 
'Max Rain Time': max_rain_time, 
'Solar Radiation median': solar_radiation_median, 
'Solar Radiation Max': solar_radiation_max, 
'Solar Radiation Max Time': solar_radiation_max_time, 
'Solar Radiation Min': solar_radiation_min, 
'Solar Radiation Min Time': solar_radiation_min_time, 
'Ultra Violet median': ultra_violet_median, 
'Ultra Violet Max': ultra_violet_max, 
'Ultra Violet Max Time': ultra_violet_max_time, 
'Ultra Violet Min': ultra_violet_min, 
'Ultra Violet Min Time': ultra_violet_min_time, 
'Distance': distance, 
'Position': Position}
# append the data to the dataframe
df = df.append(data, ignore_index=True)

# %%
muon = pd.read_csv('./week_testing/Ali.csv')
weather = pd.read_csv('./weather_data/ali_dul_weather.csv')
muon = muon[['timestamp','Chan_0_1','Chan_0_2','Chan_1_2']]
muon['timestamp'] = pd.to_datetime(muon['timestamp'])
weather.drop('Date', axis=1, inplace=True)
weather['Simple Date'] = pd.to_datetime(weather['Simple Date'])
#filter out the weather data in the range of the muon data
weather = weather[(weather['Simple Date'] >= muon['timestamp'].min()) & (weather['Simple Date'] <= muon['timestamp'].max())]
weather.set_index('Simple Date', inplace=True)
location = 'Ali Home'
date = str(muon['timestamp'].min()) + ' to ' + str(muon['timestamp'].max())
max_muon_0_1 = muon['Chan_0_1'].max()
min_muon_0_1 = muon['Chan_0_1'].min()
max_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmax()]['timestamp']
min_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmin()]['timestamp']
median_muon_0_1 = muon['Chan_0_1'].median()
max_muon_0_2 = muon['Chan_0_2'].max()
min_muon_0_2 = muon['Chan_0_2'].min()
max_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmax()]['timestamp']
min_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmin()]['timestamp']
median_muon_0_2 = muon['Chan_0_2'].median()
max_muon_1_2 = muon['Chan_1_2'].max()
min_muon_1_2 = muon['Chan_1_2'].min()
max_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmax()]['timestamp']
min_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmin()]['timestamp']
median_muon_1_2 = muon['Chan_1_2'].median()
avg_temp = weather['Outdoor Temperature (°F)'].median()
max_temp = weather['Outdoor Temperature (°F)'].max()
min_temp = weather['Outdoor Temperature (°F)'].min()
max_temp_time = weather.idxmax()['Outdoor Temperature (°F)']
min_temp_time = weather.idxmin()['Outdoor Temperature (°F)']
avg_humidity = weather['Humidity (%)'].median()
max_humidity = weather['Humidity (%)'].max()
min_humidity = weather['Humidity (%)'].min()
max_humidity_time = weather.idxmax()['Humidity (%)']
min_humidity_time = weather.idxmin()['Humidity (%)']
avg_pressure = weather['Relative Pressure (inHg)'].median()
max_pressure = weather['Relative Pressure (inHg)'].max()
min_pressure = weather['Relative Pressure (inHg)'].min()
max_pressure_time = weather.idxmax()['Relative Pressure (inHg)']
min_pressure_time = weather.idxmin()['Relative Pressure (inHg)']
is_raining = weather['Event Rain (in)'].max() > 0
max_rain = weather['Event Rain (in)'].max()
max_rain_time = weather.idxmax()['Event Rain (in)']
solar_radiation_median = weather['Solar Radiation (W/m^2)'].median()
solar_radiation_max = weather['Solar Radiation (W/m^2)'].max()
solar_radiation_max_time = weather.idxmax()['Solar Radiation (W/m^2)']
solar_radiation_min = weather['Solar Radiation (W/m^2)'].min()
solar_radiation_min_time = weather.idxmin()['Solar Radiation (W/m^2)']
ultra_violet_median = weather['Ultra-Violet Radiation Index'].median()
ultra_violet_max = weather['Ultra-Violet Radiation Index'].max()
ultra_violet_max_time = weather.idxmax()['Ultra-Violet Radiation Index']
ultra_violet_min = weather['Ultra-Violet Radiation Index'].min()
ultra_violet_min_time = weather.idxmin()['Ultra-Violet Radiation Index']
distance = calculate_distance(33.81352971779482, -84.38926914486989)
Position = 'by the study table away from the window'
# create a dictionary of the data
data = {'Location': location, 
'Date': date, 
'Max Muon_0_1': max_muon_0_1, 
'Max Muon Time_0_1': max_muon_time_0_1, 
'Min Muon_0_1': min_muon_0_1, 
'Min Muon Time_0_1': min_muon_time_0_1, 
'median Muon_0_1': median_muon_0_1,
'median Muon ceiling_0_1': ceil(median_muon_0_1),
'median Muon floor_0_1': floor(median_muon_0_1),
'median Muon round_0_1': round(median_muon_0_1),
'Max Muon_0_2': max_muon_0_2, 
'Max Muon Time_0_2': max_muon_time_0_2, 
'Min Muon_0_2': min_muon_0_2, 
'Min Muon Time_0_2': min_muon_time_0_2, 
'median Muon_0_2': median_muon_0_2,
'median Muon ceiling_0_2': ceil(median_muon_0_2),
'median Muon floor_0_2': floor(median_muon_0_2),
'median Muon round_0_2': round(median_muon_0_2),
'Max Muon_1_2': max_muon_1_2, 
'Max Muon Time_1_2': max_muon_time_1_2, 
'Min Muon_1_2': min_muon_1_2, 
'Min Muon Time_1_2': min_muon_time_1_2, 
'median Muon_1_2': median_muon_1_2,
'median Muon ceiling_1_2': ceil(median_muon_1_2),
'median Muon floor_1_2': floor(median_muon_1_2),
'median Muon round_1_2': round(median_muon_1_2),
'Avg Temp': avg_temp, 
'Max Temp': max_temp, 
'Max Temp Time': max_temp_time,
'Min Temp': min_temp,  
'Min Temp Time': min_temp_time, 
'Avg Humidity': avg_humidity, 
'Max Humidity': max_humidity, 
'Max Humidity Time': max_humidity_time,
'Min Humidity': min_humidity,  
'Min Humidity Time': min_humidity_time, 
'Avg Pressure': avg_pressure, 
'Max Pressure': max_pressure, 
'Max Pressure Time': max_pressure_time,
'Min Pressure': min_pressure,  
'Min Pressure Time': min_pressure_time, 
'Is Raining': is_raining, 
'Max Rain': max_rain, 
'Max Rain Time': max_rain_time, 
'Solar Radiation median': solar_radiation_median, 
'Solar Radiation Max': solar_radiation_max, 
'Solar Radiation Max Time': solar_radiation_max_time, 
'Solar Radiation Min': solar_radiation_min, 
'Solar Radiation Min Time': solar_radiation_min_time, 
'Ultra Violet median': ultra_violet_median, 
'Ultra Violet Max': ultra_violet_max, 
'Ultra Violet Max Time': ultra_violet_max_time, 
'Ultra Violet Min': ultra_violet_min, 
'Ultra Violet Min Time': ultra_violet_min_time, 
'Distance': distance, 
'Position': Position}
# append the data to the dataframe
df = df.append(data, ignore_index=True)

# %%
muon = pd.read_csv('./week_testing/Dulmini.csv')
weather = pd.read_csv('./weather_data/ali_dul_weather.csv')
muon = muon[['timestamp','Chan_0_1','Chan_0_2','Chan_1_2']]
muon['timestamp'] = pd.to_datetime(muon['timestamp'])
weather.drop('Date', axis=1, inplace=True)
weather['Simple Date'] = pd.to_datetime(weather['Simple Date'])
#filter out the weather data in the range of the muon data
weather = weather[(weather['Simple Date'] >= muon['timestamp'].min()) & (weather['Simple Date'] <= muon['timestamp'].max())]
weather.set_index('Simple Date', inplace=True)
location = 'Dulmini Home'
date = str(muon['timestamp'].min()) + ' to ' + str(muon['timestamp'].max())
max_muon_0_1 = muon['Chan_0_1'].max()
min_muon_0_1 = muon['Chan_0_1'].min()
max_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmax()]['timestamp']
min_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmin()]['timestamp']
median_muon_0_1 = muon['Chan_0_1'].median()
max_muon_0_2 = muon['Chan_0_2'].max()
min_muon_0_2 = muon['Chan_0_2'].min()
max_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmax()]['timestamp']
min_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmin()]['timestamp']
median_muon_0_2 = muon['Chan_0_2'].median()
max_muon_1_2 = muon['Chan_1_2'].max()
min_muon_1_2 = muon['Chan_1_2'].min()
max_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmax()]['timestamp']
min_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmin()]['timestamp']
median_muon_1_2 = muon['Chan_1_2'].median()
avg_temp = weather['Outdoor Temperature (°F)'].median()
max_temp = weather['Outdoor Temperature (°F)'].max()
min_temp = weather['Outdoor Temperature (°F)'].min()
max_temp_time = weather.idxmax()['Outdoor Temperature (°F)']
min_temp_time = weather.idxmin()['Outdoor Temperature (°F)']
avg_humidity = weather['Humidity (%)'].median()
max_humidity = weather['Humidity (%)'].max()
min_humidity = weather['Humidity (%)'].min()
max_humidity_time = weather.idxmax()['Humidity (%)']
min_humidity_time = weather.idxmin()['Humidity (%)']
avg_pressure = weather['Relative Pressure (inHg)'].median()
max_pressure = weather['Relative Pressure (inHg)'].max()
min_pressure = weather['Relative Pressure (inHg)'].min()
max_pressure_time = weather.idxmax()['Relative Pressure (inHg)']
min_pressure_time = weather.idxmin()['Relative Pressure (inHg)']
is_raining = weather['Event Rain (in)'].max() > 0
max_rain = weather['Event Rain (in)'].max()
max_rain_time = weather.idxmax()['Event Rain (in)']
solar_radiation_median = weather['Solar Radiation (W/m^2)'].median()
solar_radiation_max = weather['Solar Radiation (W/m^2)'].max()
solar_radiation_max_time = weather.idxmax()['Solar Radiation (W/m^2)']
solar_radiation_min = weather['Solar Radiation (W/m^2)'].min()
solar_radiation_min_time = weather.idxmin()['Solar Radiation (W/m^2)']
ultra_violet_median = weather['Ultra-Violet Radiation Index'].median()
ultra_violet_max = weather['Ultra-Violet Radiation Index'].max()
ultra_violet_max_time = weather.idxmax()['Ultra-Violet Radiation Index']
ultra_violet_min = weather['Ultra-Violet Radiation Index'].min()
ultra_violet_min_time = weather.idxmin()['Ultra-Violet Radiation Index']
distance = calculate_distance(33.8249700612759, -84.36689102952592)
Position = 'by the window in the corner of the room'
# create a dictionary of the data
data = {'Location': location, 
'Date': date, 
'Max Muon_0_1': max_muon_0_1, 
'Max Muon Time_0_1': max_muon_time_0_1, 
'Min Muon_0_1': min_muon_0_1, 
'Min Muon Time_0_1': min_muon_time_0_1, 
'median Muon_0_1': median_muon_0_1,
'median Muon ceiling_0_1': ceil(median_muon_0_1),
'median Muon floor_0_1': floor(median_muon_0_1),
'median Muon round_0_1': round(median_muon_0_1),
'Max Muon_0_2': max_muon_0_2, 
'Max Muon Time_0_2': max_muon_time_0_2, 
'Min Muon_0_2': min_muon_0_2, 
'Min Muon Time_0_2': min_muon_time_0_2, 
'median Muon_0_2': median_muon_0_2,
'median Muon ceiling_0_2': ceil(median_muon_0_2),
'median Muon floor_0_2': floor(median_muon_0_2),
'median Muon round_0_2': round(median_muon_0_2),
'Max Muon_1_2': max_muon_1_2, 
'Max Muon Time_1_2': max_muon_time_1_2, 
'Min Muon_1_2': min_muon_1_2, 
'Min Muon Time_1_2': min_muon_time_1_2, 
'median Muon_1_2': median_muon_1_2,
'median Muon ceiling_1_2': ceil(median_muon_1_2),
'median Muon floor_1_2': floor(median_muon_1_2),
'median Muon round_1_2': round(median_muon_1_2),
'Avg Temp': avg_temp, 
'Max Temp': max_temp, 
'Max Temp Time': max_temp_time,
'Min Temp': min_temp,  
'Min Temp Time': min_temp_time, 
'Avg Humidity': avg_humidity, 
'Max Humidity': max_humidity, 
'Max Humidity Time': max_humidity_time,
'Min Humidity': min_humidity,  
'Min Humidity Time': min_humidity_time, 
'Avg Pressure': avg_pressure, 
'Max Pressure': max_pressure, 
'Max Pressure Time': max_pressure_time,
'Min Pressure': min_pressure,  
'Min Pressure Time': min_pressure_time, 
'Is Raining': is_raining, 
'Max Rain': max_rain, 
'Max Rain Time': max_rain_time, 
'Solar Radiation median': solar_radiation_median, 
'Solar Radiation Max': solar_radiation_max, 
'Solar Radiation Max Time': solar_radiation_max_time, 
'Solar Radiation Min': solar_radiation_min, 
'Solar Radiation Min Time': solar_radiation_min_time, 
'Ultra Violet median': ultra_violet_median, 
'Ultra Violet Max': ultra_violet_max, 
'Ultra Violet Max Time': ultra_violet_max_time, 
'Ultra Violet Min': ultra_violet_min, 
'Ultra Violet Min Time': ultra_violet_min_time, 
'Distance': distance, 
'Position': Position}
# append the data to the dataframe
df = df.append(data, ignore_index=True)

# %%
muon = pd.read_csv('./week_testing/samantha_data.csv')
weather = pd.read_csv('./weather_data/samantha_weather.csv')
muon = muon[['timestamp','Chan_0_1','Chan_0_2','Chan_1_2']]
muon['timestamp'] = pd.to_datetime(muon['timestamp'])
weather.drop('Date', axis=1, inplace=True)
weather['Simple Date'] = pd.to_datetime(weather['Simple Date'])
#filter out the weather data in the range of the muon data
weather = weather[(weather['Simple Date'] >= muon['timestamp'].min()) & (weather['Simple Date'] <= muon['timestamp'].max())]
weather.set_index('Simple Date', inplace=True)
location = 'Samantha Office'
date = str(muon['timestamp'].min()) + ' to ' + str(muon['timestamp'].max())
max_muon_0_1 = muon['Chan_0_1'].max()
min_muon_0_1 = muon['Chan_0_1'].min()
max_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmax()]['timestamp']
min_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmin()]['timestamp']
median_muon_0_1 = muon['Chan_0_1'].median()
max_muon_0_2 = muon['Chan_0_2'].max()
min_muon_0_2 = muon['Chan_0_2'].min()
max_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmax()]['timestamp']
min_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmin()]['timestamp']
median_muon_0_2 = muon['Chan_0_2'].median()
max_muon_1_2 = muon['Chan_1_2'].max()
min_muon_1_2 = muon['Chan_1_2'].min()
max_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmax()]['timestamp']
min_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmin()]['timestamp']
median_muon_1_2 = muon['Chan_1_2'].median()
avg_temp = weather['Outdoor Temperature (°F)'].median()
max_temp = weather['Outdoor Temperature (°F)'].max()
min_temp = weather['Outdoor Temperature (°F)'].min()
max_temp_time = weather.idxmax()['Outdoor Temperature (°F)']
min_temp_time = weather.idxmin()['Outdoor Temperature (°F)']
avg_humidity = weather['Humidity (%)'].median()
max_humidity = weather['Humidity (%)'].max()
min_humidity = weather['Humidity (%)'].min()
max_humidity_time = weather.idxmax()['Humidity (%)']
min_humidity_time = weather.idxmin()['Humidity (%)']
avg_pressure = weather['Relative Pressure (inHg)'].median()
max_pressure = weather['Relative Pressure (inHg)'].max()
min_pressure = weather['Relative Pressure (inHg)'].min()
max_pressure_time = weather.idxmax()['Relative Pressure (inHg)']
min_pressure_time = weather.idxmin()['Relative Pressure (inHg)']
is_raining = weather['Event Rain (in)'].max() > 0
max_rain = weather['Event Rain (in)'].max()
max_rain_time = weather.idxmax()['Event Rain (in)']
solar_radiation_median = weather['Solar Radiation (W/m^2)'].median()
solar_radiation_max = weather['Solar Radiation (W/m^2)'].max()
solar_radiation_max_time = weather.idxmax()['Solar Radiation (W/m^2)']
solar_radiation_min = weather['Solar Radiation (W/m^2)'].min()
solar_radiation_min_time = weather.idxmin()['Solar Radiation (W/m^2)']
ultra_violet_median = weather['Ultra-Violet Radiation Index'].median()
ultra_violet_max = weather['Ultra-Violet Radiation Index'].max()
ultra_violet_max_time = weather.idxmax()['Ultra-Violet Radiation Index']
ultra_violet_min = weather['Ultra-Violet Radiation Index'].min()
ultra_violet_min_time = weather.idxmin()['Ultra-Violet Radiation Index']
distance = calculate_distance(33.68909001334597, -84.27484225836585)
Position = 'by the window in the corner of the room'
# create a dictionary of the data
data = {'Location': location, 
'Date': date, 
'Max Muon_0_1': max_muon_0_1, 
'Max Muon Time_0_1': max_muon_time_0_1, 
'Min Muon_0_1': min_muon_0_1, 
'Min Muon Time_0_1': min_muon_time_0_1, 
'median Muon_0_1': median_muon_0_1,
'median Muon ceiling_0_1': ceil(median_muon_0_1),
'median Muon floor_0_1': floor(median_muon_0_1),
'median Muon round_0_1': round(median_muon_0_1),
'Max Muon_0_2': max_muon_0_2, 
'Max Muon Time_0_2': max_muon_time_0_2, 
'Min Muon_0_2': min_muon_0_2, 
'Min Muon Time_0_2': min_muon_time_0_2, 
'median Muon_0_2': median_muon_0_2,
'median Muon ceiling_0_2': ceil(median_muon_0_2),
'median Muon floor_0_2': floor(median_muon_0_2),
'median Muon round_0_2': round(median_muon_0_2),
'Max Muon_1_2': max_muon_1_2, 
'Max Muon Time_1_2': max_muon_time_1_2, 
'Min Muon_1_2': min_muon_1_2, 
'Min Muon Time_1_2': min_muon_time_1_2, 
'median Muon_1_2': median_muon_1_2,
'median Muon ceiling_1_2': ceil(median_muon_1_2),
'median Muon floor_1_2': floor(median_muon_1_2),
'median Muon round_1_2': round(median_muon_1_2),
'Avg Temp': avg_temp, 
'Max Temp': max_temp, 
'Max Temp Time': max_temp_time,
'Min Temp': min_temp,  
'Min Temp Time': min_temp_time, 
'Avg Humidity': avg_humidity, 
'Max Humidity': max_humidity, 
'Max Humidity Time': max_humidity_time,
'Min Humidity': min_humidity,  
'Min Humidity Time': min_humidity_time, 
'Avg Pressure': avg_pressure, 
'Max Pressure': max_pressure, 
'Max Pressure Time': max_pressure_time,
'Min Pressure': min_pressure,  
'Min Pressure Time': min_pressure_time, 
'Is Raining': is_raining, 
'Max Rain': max_rain, 
'Max Rain Time': max_rain_time, 
'Solar Radiation median': solar_radiation_median, 
'Solar Radiation Max': solar_radiation_max, 
'Solar Radiation Max Time': solar_radiation_max_time, 
'Solar Radiation Min': solar_radiation_min, 
'Solar Radiation Min Time': solar_radiation_min_time, 
'Ultra Violet median': ultra_violet_median, 
'Ultra Violet Max': ultra_violet_max, 
'Ultra Violet Max Time': ultra_violet_max_time, 
'Ultra Violet Min': ultra_violet_min, 
'Ultra Violet Min Time': ultra_violet_min_time, 
'Distance': distance, 
'Position': Position}
# append the data to the dataframe
df = df.append(data, ignore_index=True)

# %%
muon = pd.read_csv('./week_testing/leslie_data.csv')
weather = pd.read_csv('./weather_data/leslie_weather.csv')
muon = muon[['timestamp','Chan_0_1','Chan_0_2','Chan_1_2']]
muon['timestamp'] = pd.to_datetime(muon['timestamp'])
weather.drop('Date', axis=1, inplace=True)
weather['Simple Date'] = pd.to_datetime(weather['Simple Date'])
#filter out the weather data in the range of the muon data
weather = weather[(weather['Simple Date'] >= muon['timestamp'].min()) & (weather['Simple Date'] <= muon['timestamp'].max())]
weather.set_index('Simple Date', inplace=True)
location = 'Leslie Home'
date = str(muon['timestamp'].min()) + ' to ' + str(muon['timestamp'].max())
max_muon_0_1 = muon['Chan_0_1'].max()
min_muon_0_1 = muon['Chan_0_1'].min()
max_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmax()]['timestamp']
min_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmin()]['timestamp']
median_muon_0_1 = muon['Chan_0_1'].median()
max_muon_0_2 = muon['Chan_0_2'].max()
min_muon_0_2 = muon['Chan_0_2'].min()
max_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmax()]['timestamp']
min_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmin()]['timestamp']
median_muon_0_2 = muon['Chan_0_2'].median()
max_muon_1_2 = muon['Chan_1_2'].max()
min_muon_1_2 = muon['Chan_1_2'].min()
max_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmax()]['timestamp']
min_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmin()]['timestamp']
median_muon_1_2 = muon['Chan_1_2'].median()
avg_temp = weather['Outdoor Temperature (°F)'].median()
max_temp = weather['Outdoor Temperature (°F)'].max()
min_temp = weather['Outdoor Temperature (°F)'].min()
max_temp_time = weather.idxmax()['Outdoor Temperature (°F)']
min_temp_time = weather.idxmin()['Outdoor Temperature (°F)']
avg_humidity = weather['Humidity (%)'].median()
max_humidity = weather['Humidity (%)'].max()
min_humidity = weather['Humidity (%)'].min()
max_humidity_time = weather.idxmax()['Humidity (%)']
min_humidity_time = weather.idxmin()['Humidity (%)']
avg_pressure = weather['Relative Pressure (inHg)'].median()
max_pressure = weather['Relative Pressure (inHg)'].max()
min_pressure = weather['Relative Pressure (inHg)'].min()
max_pressure_time = weather.idxmax()['Relative Pressure (inHg)']
min_pressure_time = weather.idxmin()['Relative Pressure (inHg)']
is_raining = weather['Event Rain (in)'].max() > 0
max_rain = weather['Event Rain (in)'].max()
max_rain_time = weather.idxmax()['Event Rain (in)']
solar_radiation_median = weather['Solar Radiation (W/m^2)'].median()
solar_radiation_max = weather['Solar Radiation (W/m^2)'].max()
solar_radiation_max_time = weather.idxmax()['Solar Radiation (W/m^2)']
solar_radiation_min = weather['Solar Radiation (W/m^2)'].min()
solar_radiation_min_time = weather.idxmin()['Solar Radiation (W/m^2)']
ultra_violet_median = weather['Ultra-Violet Radiation Index'].median()
ultra_violet_max = weather['Ultra-Violet Radiation Index'].max()
ultra_violet_max_time = weather.idxmax()['Ultra-Violet Radiation Index']
ultra_violet_min = weather['Ultra-Violet Radiation Index'].min()
ultra_violet_min_time = weather.idxmin()['Ultra-Violet Radiation Index']
distance = calculate_distance(33.77662104719059, -84.29956063137874)
Position = 'by the window'
# create a dictionary of the data
data = {'Location': location, 
'Date': date, 
'Max Muon_0_1': max_muon_0_1, 
'Max Muon Time_0_1': max_muon_time_0_1, 
'Min Muon_0_1': min_muon_0_1, 
'Min Muon Time_0_1': min_muon_time_0_1, 
'median Muon_0_1': median_muon_0_1,
'median Muon ceiling_0_1': ceil(median_muon_0_1),
'median Muon floor_0_1': floor(median_muon_0_1),
'median Muon round_0_1': round(median_muon_0_1),
'Max Muon_0_2': max_muon_0_2, 
'Max Muon Time_0_2': max_muon_time_0_2, 
'Min Muon_0_2': min_muon_0_2, 
'Min Muon Time_0_2': min_muon_time_0_2, 
'median Muon_0_2': median_muon_0_2,
'median Muon ceiling_0_2': ceil(median_muon_0_2),
'median Muon floor_0_2': floor(median_muon_0_2),
'median Muon round_0_2': round(median_muon_0_2),
'Max Muon_1_2': max_muon_1_2, 
'Max Muon Time_1_2': max_muon_time_1_2, 
'Min Muon_1_2': min_muon_1_2, 
'Min Muon Time_1_2': min_muon_time_1_2, 
'median Muon_1_2': median_muon_1_2,
'median Muon ceiling_1_2': ceil(median_muon_1_2),
'median Muon floor_1_2': floor(median_muon_1_2),
'median Muon round_1_2': round(median_muon_1_2),
'Avg Temp': avg_temp, 
'Max Temp': max_temp, 
'Max Temp Time': max_temp_time,
'Min Temp': min_temp,  
'Min Temp Time': min_temp_time, 
'Avg Humidity': avg_humidity, 
'Max Humidity': max_humidity, 
'Max Humidity Time': max_humidity_time,
'Min Humidity': min_humidity,  
'Min Humidity Time': min_humidity_time, 
'Avg Pressure': avg_pressure, 
'Max Pressure': max_pressure, 
'Max Pressure Time': max_pressure_time,
'Min Pressure': min_pressure,  
'Min Pressure Time': min_pressure_time, 
'Is Raining': is_raining, 
'Max Rain': max_rain, 
'Max Rain Time': max_rain_time, 
'Solar Radiation median': solar_radiation_median, 
'Solar Radiation Max': solar_radiation_max, 
'Solar Radiation Max Time': solar_radiation_max_time, 
'Solar Radiation Min': solar_radiation_min, 
'Solar Radiation Min Time': solar_radiation_min_time, 
'Ultra Violet median': ultra_violet_median, 
'Ultra Violet Max': ultra_violet_max, 
'Ultra Violet Max Time': ultra_violet_max_time, 
'Ultra Violet Min': ultra_violet_min, 
'Ultra Violet Min Time': ultra_violet_min_time, 
'Distance': distance, 
'Position': Position}
# append the data to the dataframe
df = df.append(data, ignore_index=True)

# %%
muon = pd.read_csv('./week_testing/stone_mountain_data.csv')
weather = pd.read_csv('./weather_data/stone_mountain_weather.csv')
muon = muon[['timestamp','Chan_0_1','Chan_0_2','Chan_1_2']]
muon['timestamp'] = pd.to_datetime(muon['timestamp'])
weather.drop('Date', axis=1, inplace=True)
weather['Simple Date'] = pd.to_datetime(weather['Simple Date'])
#filter out the weather data in the range of the muon data
weather = weather[(weather['Simple Date'] >= muon['timestamp'].min()) & (weather['Simple Date'] <= muon['timestamp'].max())]
weather.set_index('Simple Date', inplace=True)
location = 'Stone Mountain Outdoor box'
date = str(muon['timestamp'].min()) + ' to ' + str(muon['timestamp'].max())
max_muon_0_1 = muon['Chan_0_1'].max()
min_muon_0_1 = muon['Chan_0_1'].min()
max_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmax()]['timestamp']
min_muon_time_0_1 = muon.iloc[muon['Chan_0_1'].idxmin()]['timestamp']
median_muon_0_1 = muon['Chan_0_1'].median()
max_muon_0_2 = muon['Chan_0_2'].max()
min_muon_0_2 = muon['Chan_0_2'].min()
max_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmax()]['timestamp']
min_muon_time_0_2 = muon.iloc[muon['Chan_0_2'].idxmin()]['timestamp']
median_muon_0_2 = muon['Chan_0_2'].median()
max_muon_1_2 = muon['Chan_1_2'].max()
min_muon_1_2 = muon['Chan_1_2'].min()
max_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmax()]['timestamp']
min_muon_time_1_2 = muon.iloc[muon['Chan_1_2'].idxmin()]['timestamp']
median_muon_1_2 = muon['Chan_1_2'].median()
avg_temp = weather['Outdoor h Temperature (°F)'].median()
max_temp = weather['Outdoor h Temperature (°F)'].max()
min_temp = weather['Outdoor h Temperature (°F)'].min()
max_temp_time = weather.idxmax()['Outdoor h Temperature (°F)']
min_temp_time = weather.idxmin()['Outdoor h Temperature (°F)']
avg_humidity = weather['Humidity (%)'].median()
max_humidity = weather['Humidity (%)'].max()
min_humidity = weather['Humidity (%)'].min()
max_humidity_time = weather.idxmax()['Humidity (%)']
min_humidity_time = weather.idxmin()['Humidity (%)']
avg_pressure = weather['Relative Pressure (inHg)'].median()
max_pressure = weather['Relative Pressure (inHg)'].max()
min_pressure = weather['Relative Pressure (inHg)'].min()
max_pressure_time = weather.idxmax()['Relative Pressure (inHg)']
min_pressure_time = weather.idxmin()['Relative Pressure (inHg)']
is_raining = weather['Event Rain (in)'].max() > 0
max_rain = weather['Event Rain (in)'].max()
max_rain_time = weather.idxmax()['Event Rain (in)']
solar_radiation_median = weather['Solar Radiation (W/m^2)'].median()
solar_radiation_max = weather['Solar Radiation (W/m^2)'].max()
solar_radiation_max_time = weather.idxmax()['Solar Radiation (W/m^2)']
solar_radiation_min = weather['Solar Radiation (W/m^2)'].min()
solar_radiation_min_time = weather.idxmin()['Solar Radiation (W/m^2)']
ultra_violet_median = weather['Ultra-Violet Radiation Index'].median()
ultra_violet_max = weather['Ultra-Violet Radiation Index'].max()
ultra_violet_max_time = weather.idxmax()['Ultra-Violet Radiation Index']
ultra_violet_min = weather['Ultra-Violet Radiation Index'].min()
ultra_violet_min_time = weather.idxmin()['Ultra-Violet Radiation Index']
distance = calculate_distance(33.81164183803373, -84.1620300024976)
Position = 'Outdoor box'
# create a dictionary of the data
data = {'Location': location, 
'Date': date, 
'Max Muon_0_1': max_muon_0_1, 
'Max Muon Time_0_1': max_muon_time_0_1, 
'Min Muon_0_1': min_muon_0_1, 
'Min Muon Time_0_1': min_muon_time_0_1, 
'median Muon_0_1': median_muon_0_1,
'median Muon ceiling_0_1': ceil(median_muon_0_1),
'median Muon floor_0_1': floor(median_muon_0_1),
'median Muon round_0_1': round(median_muon_0_1),
'Max Muon_0_2': max_muon_0_2, 
'Max Muon Time_0_2': max_muon_time_0_2, 
'Min Muon_0_2': min_muon_0_2, 
'Min Muon Time_0_2': min_muon_time_0_2, 
'median Muon_0_2': median_muon_0_2,
'median Muon ceiling_0_2': ceil(median_muon_0_2),
'median Muon floor_0_2': floor(median_muon_0_2),
'median Muon round_0_2': round(median_muon_0_2),
'Max Muon_1_2': max_muon_1_2, 
'Max Muon Time_1_2': max_muon_time_1_2, 
'Min Muon_1_2': min_muon_1_2, 
'Min Muon Time_1_2': min_muon_time_1_2, 
'median Muon_1_2': median_muon_1_2,
'median Muon ceiling_1_2': ceil(median_muon_1_2),
'median Muon floor_1_2': floor(median_muon_1_2),
'median Muon round_1_2': round(median_muon_1_2),
'Avg Temp': avg_temp, 
'Max Temp': max_temp, 
'Max Temp Time': max_temp_time,
'Min Temp': min_temp,  
'Min Temp Time': min_temp_time, 
'Avg Humidity': avg_humidity, 
'Max Humidity': max_humidity, 
'Max Humidity Time': max_humidity_time,
'Min Humidity': min_humidity,  
'Min Humidity Time': min_humidity_time, 
'Avg Pressure': avg_pressure, 
'Max Pressure': max_pressure, 
'Max Pressure Time': max_pressure_time,
'Min Pressure': min_pressure,  
'Min Pressure Time': min_pressure_time, 
'Is Raining': is_raining, 
'Max Rain': max_rain, 
'Max Rain Time': max_rain_time, 
'Solar Radiation median': solar_radiation_median, 
'Solar Radiation Max': solar_radiation_max, 
'Solar Radiation Max Time': solar_radiation_max_time, 
'Solar Radiation Min': solar_radiation_min, 
'Solar Radiation Min Time': solar_radiation_min_time, 
'Ultra Violet median': ultra_violet_median, 
'Ultra Violet Max': ultra_violet_max, 
'Ultra Violet Max Time': ultra_violet_max_time, 
'Ultra Violet Min': ultra_violet_min, 
'Ultra Violet Min Time': ultra_violet_min_time, 
'Distance': distance, 
'Position': Position}
# append the data to the dataframe
df = df.append(data, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/toripad24/cubesat/geo_testing/tabular_data.ipynb Cell 5 in 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/toripad24/cubesat/geo_testing/tabular_data.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> muon['timestamp'] = pd.to_datetime(muon['timestamp'])
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/toripad24/cubesat/geo_testing/tabular_data.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> muon = muon['timestamp'].dt.floor('1min')
#
# TypeError: list indices must be integers or slices, not str

# %%
df
# Out:
#                      Location                                        Date  \
# 0                 Abbaas Home  2023-03-25 13:32:08 to 2023-03-26 14:11:09
# 1                   Andy Home  2023-03-31 22:00:38 to 2023-04-02 12:24:32
# 2                    Ali Home  2023-03-27 15:25:24 to 2023-03-28 15:45:24
# 3                Dulmini Home  2023-03-28 16:18:39 to 2023-03-29 16:17:23
# 4             Samantha Office  2023-03-29 15:19:06 to 2023-03-30 17:32:33
# 5                 Leslie Home  2023-03-30 17:18:33 to 2023-03-31 22:09:38
# 6  Stone Mountain Outdoor box  2023-04-02 13:18:06 to 2023-04-03 22:39:25
#
#    Max Muon_0_1   Max Muon Time_0_1  Min Muon_0_1   Min Muon Time_0_1  \
# 0            15 2023-03-25 13:56:08             0 2023-03-25 14:51:08
# 1          1284 2023-03-31 22:22:31             0 2023-03-31 22:01:38
# 2           248 2023-03-27 22:41:24             2 2023-03-27 15:25:24
# 3           290 2023-03-29 15:18:06             2 2023-03-28 16:22:44
# ...

# %%
df.to_csv('muon_weather_data.csv', index=False)
